# %%
import pandas as pd
import pymysql 
import sqlalchemy
import MySQLdb
import matplotlib.pyplot as plt

memes = sqlalchemy.create_engine('mysql+pymysql://root:neltab1994##@localhost/my_first')
df = pd.read_sql_table('sprint_1', memes)
df
# Out:
#    Barcode                 Product Type:             Product     Price  \
# 0                                  Chips               Lay's    R7,50
# 1                                                      Simba    R7,50
# 2                                                    Bubbles    R9,00
# 3                                                   Nik Naks    R1,50
# 4                                                 Bigga Naks    R1,00
# 5                     Cooldrinks (500ml)                Coke   R11,00
# 6                                                      Fanta   R11,00
# 7                                                     Sprite   R11,00
# 8                                                      Pepsi    R9,00
# 9                                                        7Up    R9,00
# 10                                              Mountain Dew    R9,00
# 11                      Chocolate(Slabs)            Cadbury    R12,00
# ...

# %%
#To check if table exists

mycursor.execute("SHOW TABLES")

for x in mycursor:
     print(x)

# %%
#Creating Chips Table
import pandas as pd
import pymysql 
import sqlalchemy
import MySQLdb
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Chips (Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")

# %%
import pymysql
#pymysql.install_as_MySQLdb()
import MySQLdb

db= MySQLdb.connect("localhost", "root", "neltab1994##", "my_first")

cursor= db.cursor()

cursor.execute("ALTER TABLE Chips ADD Barcode VARCHAR(100) NOT NULL FIRST ")

db.close()

# %%
#Inserting data into chips table

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

sql = "INSERT INTO Chips (Product, Price, Quantity, Sold, Sales) VALUES (%s, %s, %s, %s, %s)"
val = [
  ('Lays', '7.50', '50', '15', '112.50'),
    ('Simba', '7.50', '50', '21', '112.50'),
    ('Bigga Naks', '1.00', '50', '45', '45.00'),
    ('Bubbles', '9.00', '30', '12', '108.00'),
    ('Nik Naks', '1.50', '50', '40', '60.00')
  
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")

# %%
#Creating Chocolate Table
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Chocolate (Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'chocolate' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-0a7d81fde38d> in <module>
#      10 mycursor = mydb.cursor()
#      11
# ---> 12 mycursor.execute("CREATE TABLE Chocolate (Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")
#
# ...

# %%
#Creating Cooldrinks Table
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Cooldrinks (Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")

# %%
import pymysql
#pymysql.install_as_MySQLdb()
import MySQLdb

db= MySQLdb.connect("localhost", "root", "neltab1994##", "my_first")

cursor= db.cursor()

cursor.execute("ALTER TABLE Cooldrinks ADD Barcode VARCHAR(100) NOT NULL FIRST ")

db.close()

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

sql = "INSERT INTO Cooldrinks (Product, Price, Quantity, Sold, Sales) VALUES (%s, %s, %s, %s, %s)"
val = [
  ('Coke', '11.00', '30', '15', '180.50'),
    ('Pepsi', '9.00', '30', '17', '187.00'),
    ('Sprite', '11.00', '50', '45', '630.00'),
    ('7Up', '9.00', '30', '12', '180.00'),
    ('Mountain Dew', '9.00', '50', '40', '740.00')
  
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")

# %%
#Creating Cooldrinks Table
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Pies (Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

sql = "INSERT INTO Pies (Product, Price, Quantity, Sold, Sales) VALUES (%s, %s, %s, %s, %s)"
val = [
  ('Chicken & Mushroom', '18.00', '20', '15', '270.00'),
    ('Pepper Steak', '18.00', '20', '10', '180.00'),
    ('Burger', '20.00', '20', '14', '280.00'),
    ('Spinach & Fetta', '23.00', '25', '20', '460.00'),
    
  
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# 4 was inserted.

# %%
#Creating Cooldrinks Table
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE FriutsandVegitables(Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

sql = "INSERT INTO FriutsandVegitables (Product, Price, Quantity, Sold, Sales) VALUES (%s, %s, %s, %s, %s)"
val = [
  ('Apples', '11.00', '30', '15', '180.50'),
    ('Potatoes', '9.00', '30', '17', '187.00'),
    ('Bananas', '11.00', '50', '45', '630.00'),
    ('Grapes', '9.00', '30', '12', '180.00'),
    ('Onions', '9.00', '50', '40', '740.00')
  
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")

# %%
#Creating Cooldrinks Table
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Cupcakes(Product VARCHAR(255), Price VARCHAR(255), Quantity INT, Sold INT, Sales VARCHAR(255) )")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="neltab1994##",
  database="my_first"
)

mycursor = mydb.cursor()

sql = "INSERT INTO Cupcakes (Product, Price, Quantity, Sold, Sales) VALUES (%s, %s, %s, %s, %s)"
val = [
  ('Vanilla', '15.00', '24', '15', '225.00'),
    ('Chocolate', '15.00', '24', '16', '240.00'),
    ('Red Velvet', '18.00', '24', '10', '180.00'),
    ('Cuppaccino', '15.00', '24', '20', '300.00'),
    
  
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# 4 was inserted.

# %%
import pymysql
#pymysql.install_as_MySQLdb()
import MySQLdb

db= MySQLdb.connect("localhost", "root", "neltab1994##", "my_first")

cursor= db.cursor()

cursor.execute("ALTER TABLE Pies ADD Barcode VARCHAR(100) NOT NULL FIRST ")

db.close()

# %%
import pymysql
#pymysql.install_as_MySQLdb()
import MySQLdb

db= MySQLdb.connect("localhost", "root", "neltab1994##", "my_first")

cursor= db.cursor()

cursor.execute("ALTER TABLE FriutsandVegitables ADD Barcode VARCHAR(100) NOT NULL FIRST ")

db.close()

# %%
import pymysql
#pymysql.install_as_MySQLdb()
import MySQLdb

db= MySQLdb.connect("localhost", "root", "neltab1994##", "my_first")

cursor= db.cursor()

cursor.execute("ALTER TABLE chocolate ADD Barcode VARCHAR(100) NOT NULL FIRST ")

db.close()
